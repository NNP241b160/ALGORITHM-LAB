# %% [markdown]
# <a href="https://colab.research.google.com/github/NNP241b160/ALGORITHM-LAB/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]


n_values = [100, 200, 300, 400, 500]
time_values = []

for n in n_values:
    numbers = [random.randint(1, 1000) for _ in range(n)]
    start_time = time.perf_counter()
    selection_sort(numbers)
    end_time = time.perf_counter()
    time_values.append((end_time - start_time) * 1000)
    print(f"Input Size: {n}, Running Time: {running_time:.6f} seconds")

plt.figure()
plt.plot(n_values, time_values, marker='o')
plt.xlabel("Input Size (n)")
plt.ylabel("Running Time (ms)")
plt.title("Selection Sort Running Time")
plt.show()
# Out:
# Input Size: 100, Running Time: 0.001067 seconds
# Input Size: 200, Running Time: 0.001067 seconds
# Input Size: 300, Running Time: 0.001067 seconds
# Input Size: 400, Running Time: 0.001067 seconds
# Input Size: 500, Running Time: 0.001067 seconds

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.

import time
import random
import matplotlib.pyplot as plt
import sys
sys.setrecursionlimit(10000)
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)
def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result
sizes = [100, 200, 400, 600, 800, 1000]
times = []
for n in sizes:
    data = random.sample(range(1, n * 10), n)
    start_time = time.time()
    merge_sort(data)
    end_time = time.time()
    running_time = end_time - start_time
    times.append(running_time)
    print(f"Input Size: {n}, Running Time: {running_time:.6f} seconds")
plt.figure()
plt.plot(sizes, times, marker='o')
plt.xlabel("Input Size (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Merge Sort Time Complexity")
plt.show()
# Out:
# Input Size: 100, Running Time: 0.000185 seconds
# Input Size: 200, Running Time: 0.000366 seconds
# Input Size: 400, Running Time: 0.000699 seconds
# Input Size: 600, Running Time: 0.003173 seconds
# Input Size: 800, Running Time: 0.002344 seconds
# Input Size: 1000, Running Time: 0.001888 seconds

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt
import sys
sys.setrecursionlimit(10000)
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

sizes = [100, 200, 300,  400, 500, 600 ]
times = []

for n in sizes:
    data = random.sample(range(1, n * 10), n)
    start_time = time.time()
    quick_sort(data)
    end_time = time.time()
    running_time = end_time - start_time
    times.append(running_time)
    print(f"Input Size: {n}, Running Time: {running_time:.6f} seconds")
plt.figure()
plt.plot(sizes, times, marker='o')
plt.xlabel("Input Size (n)")
plt.ylabel("Time Taken (seconds)")
plt.title("Quick Sort Time Complexity")
plt.show()
# Out:
# Input Size: 100, Running Time: 0.000137 seconds
# Input Size: 200, Running Time: 0.000235 seconds
# Input Size: 300, Running Time: 0.000451 seconds
# Input Size: 400, Running Time: 0.000554 seconds
# Input Size: 500, Running Time: 0.000687 seconds
# Input Size: 600, Running Time: 0.001327 seconds

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
import random
from datetime import datetime
n_max = 10000
ms = datetime.now().microsecond / 1000
random.seed(ms)
numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))
print(numbers)
# Out:
# [423, 718, 120, 474, 316, 120, 747, 797, 268, 922, 616, 677, 654, 524, 525, 827, 741, 110, 85, 84, 878, 253, 757, 46, 307, 799, 248, 920, 49, 107, 637, 780, 251, 785, 897, 912, 525, 480, 828, 381, 423, 93, 345, 616, 647, 526, 548, 422, 910, 482, 540, 281, 487, 258, 281, 402, 239, 332, 208, 918, 767, 158, 658, 708, 63, 482, 490, 302, 283, 933, 11, 41, 237, 646, 863, 49, 896, 413, 319, 69, 196, 446, 111, 951, 32, 953, 21, 808, 623, 964, 774, 59, 711, 747, 266, 333, 659, 646, 882, 478, 698, 758, 329, 69, 577, 828, 912, 868, 939, 346, 994, 482, 344, 184, 180, 458, 166, 824, 837, 347, 310, 397, 584, 355, 891, 72, 103, 909, 946, 619, 346, 796, 915, 33, 174, 751, 135, 388, 342, 818, 801, 670, 866, 365, 952, 695, 818, 453, 785, 517, 718, 47, 438, 802, 826, 61, 364, 653, 116, 100, 192, 828, 322, 471, 401, 398, 589, 261, 294, 360, 951, 573, 218, 500, 961, 845, 23, 499, 565, 541, 395, 445, 319, 135, 113, 731, 928, 36, 355, 434, 232, 324, 549, 558, 429, 594, 259, 171, 539, 223, 143, 451, 486, 145, 298, 375, 839, 97, 432, 653, 301, 918, 377, 27, 617, 319, 125, 110, 665, 786, 154, 579, 451, 673, 